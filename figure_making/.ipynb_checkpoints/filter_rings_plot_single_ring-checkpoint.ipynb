# %%
import os
import os.path as ospath
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import shutil
import glob

from picasso.picasso import io

# %%
def load_ring_data_df(dirname, filename):
    file = ospath.join(dirname, filename)

    try: 
        df = pd.read_pickle(file)
    except FileNotFoundError:
        print("No results of previously analyzed datasets were detected.")
        return None
    else: 
        print("Results of previously analyzed datasets were detected.")
        return df
    
def load_data(path):

    try:
        locs, info = io.load_locs(path)
    except io.NoMetadataFileError:
        return None, None, None
    
    try:
        pixelsize = info[1]["Pixelsize"]
    except:  
        print("No pixelsize found in yaml file. Default 130 nm used.")

        
    return locs, info, pixelsize

# %%
path = r'X:\users\kcramer\sporPAINT\ZapA\ZapA_picked_rings'



df_ring_data = load_ring_data_df(path, "ring_data.pkl")
print(df_ring_data.keys())

# radius criterium
dR = 100
perc_on_ring_min = 0.8
perc_inside_ring_max = 0.2
perc_outside_ring_max = 0.2

# angle criterium
N_segments = 12
perc_locs_per_filled_segment_min = 1/N_segments/4 # a segment counts as filled if it contains this fraction of all localizations
perc_segments_filled_min = 0.6 # this fraction of segments has to be filled to accept the ring
# Out:
# Results of previously analyzed datasets were detected.
# Index(['fov_id', 'cell_type', 'filename', 'group', 'residual', 'radius',
#        'angle_between_ring_and_coverslip', 'Sigma', 'n_events', 'mean_bright',
#        'mean_dark', 'fit_bright', 'fit_dark'],
#       dtype='object')

# %%
analysis_folder = os.path.join(path, 'analysis')
excluded_folder = os.path.join(path, 'analysis', 'excluded_filter')
if not os.path.isdir(excluded_folder):
    os.makedirs(excluded_folder)

# reset excluded_filter folder

# move fov_1_spor_pick_0.png back to analysis folder
for image_path in glob.glob(os.path.join(excluded_folder, '*.png')):
    if 'filter.png' in image_path:
        os.remove(image_path)
    else:
        image = os.path.split(image_path)[1]
        shutil.move(os.path.join(excluded_folder, image), os.path.join(analysis_folder, image))
       #shutil.move(os.path.join(analysis_folder, filename_base + '.png'), os.path.join(excluded_folder, filename_base + '.png'))

# remove _filter.png files from analysis folder
for image_path in glob.glob(os.path.join(analysis_folder, '*_filter.png')):
    if 'filter.png' in image_path:
        os.remove(image_path)

# %%
orientation = 'yz' # use yz, but also xy files contain info for filtering



# prepare bins for angle check:
# angles from -180 to 180
bin_width = 360/N_segments
bins = np.arange(-180, 180+bin_width, bin_width)


# add filter_passed column:
df_ring_data['filter_passed'] = np.full(len(df_ring_data), "No")
df_ring_data['filename_ring'] =  'fov_' + df_ring_data['fov_id'].astype(str) +'_' + df_ring_data['cell_type'].astype(str) +'_pick_' + df_ring_data['group'].astype(str) +'_ring_' + '0' +'_rot_' + orientation + '_update.hdf5'
for index, ring in df_ring_data.iterrows():
    plt.close('all')
    locs, info, pixelsize = load_data(os.path.join(path, 'analysis', 'ring_locs', ring['filename_ring'] ))
    
    radius_fit = ring['radius']
    radius_min = radius_fit - dR
    radius_max = radius_fit + dR
    
    
    N_locs = len(locs)

    ################
    # Check if radius criterium is fulfilled.
    ################
    
    perc_on_ring = len(locs[(locs['radius']>radius_min) & (locs['radius']<radius_max)]) / N_locs
    perc_inside_ring = len(locs[locs['radius']<radius_min]) / N_locs
    perc_outside_ring = len(locs[locs['radius']>radius_max]) / N_locs
    
    radius_criterium = perc_on_ring >= perc_on_ring_min and perc_inside_ring <= perc_inside_ring_max and perc_outside_ring <= perc_outside_ring_max
    
    #print(perc_on_ring, perc_on_ring >= perc_on_ring_min)
    #print(perc_inside_ring, perc_inside_ring <= perc_inside_ring_max)
    #print(perc_outside_ring, perc_outside_ring <= perc_outside_ring_max)
    #print(radius_criterium, radius_criterium)
    #print()
    
    ################
    # Check if angle criterium is fulfilled.
    ################
    print(ring['filename_ring'])
    df_locs = pd.DataFrame.from_records(locs)
    
    # consider only locs on ring
    df_locs_not_ring = df_locs[(df_locs['radius']<radius_min) | (df_locs['radius']>radius_max)]
    df_locs_ring = df_locs[(df_locs['radius']>radius_min) & (df_locs['radius']<radius_max)]
    N_locs_ring = len(df_locs_ring)
    
    perc_locs_per_segment = df_locs_ring['angle'].groupby(pd.cut(df_locs_ring['angle'], bins = bins)).count()/N_locs_ring
    print(perc_locs_per_segment)
    #print(perc_locs_per_filled_segment_min)
    perc_locs_per_segments_filled = perc_locs_per_segment[perc_locs_per_segment>perc_locs_per_filled_segment_min]
    perc_segments_filled = len(perc_locs_per_segments_filled)/N_segments
    print('perc_locs_per_segments_filled', perc_locs_per_segments_filled)
    #print('perc_segments_filled', perc_segments_filled)
    #print('perc_segments_filled_min', perc_segments_filled_min)
    
    angle_criterium = perc_segments_filled >= perc_segments_filled_min
    #print(angle_criterium)
    #print()
    


    ################
    # Plot
    ################    
    
    # set up plot illustrating analysis parameters
    fig = plt.figure(figsize=(20, 10), constrained_layout=True)
    gs = fig.add_gridspec(1,2)
    fig.suptitle(("FOV {}, {}, Pick {} - Ring analysis\n"
                  "File: {}\n").format(ring['fov_id'], ring['cell_type'] , ring['group'], ring['filename']), 
                 fontsize=16, 
                 ha="center")

    # set maximum radius for plot such that 99% of locs are shown
    cutoff = 1

    radius_sort = np.sort(locs['radius'])
    radius_limit = radius_sort[int(cutoff*len(radius_sort))-1]

    ## ring criterium
    ax_1 = fig.add_subplot(gs[0, 0], projection='polar')
    
    ax_1.set_xticks(bins[1:]/180*np.pi)
    ax_1.set_thetalim(-np.pi,np.pi)

    #ring of fit radius
    coords_angle_fit = np.arange(-np.pi,np.pi,0.01)
    coords_radius_fit = np.full(len(coords_angle_fit), radius_fit)
    coords_radius_min = np.full(len(coords_angle_fit), radius_min)
    coords_radius_max = np.full(len(coords_angle_fit), radius_max)
    
    ax_1.fill_between(coords_angle_fit,radius_min, radius_max, color='red', alpha=0.2)

    ax_1.plot(coords_angle_fit, coords_radius_fit, c='red', lw=2)
    ax_1.plot(coords_angle_fit, coords_radius_min, c='red', lw=1)
    ax_1.plot(coords_angle_fit, coords_radius_max, c='red', lw=1)
    
    # locs
    ax_1.scatter(locs['angle']/180*np.pi, locs['radius'], alpha=0.5)
    
    
    # set maximum radius for plot such that 99% of locs are shown
    ax_1.set_rmax(radius_limit)

    ax_1.set_title('Localizations within ring\n\n\n\n\n', fontsize = 16)
    
    annotate_y = 0.85
    plt.annotate("Fit radius: {:.1f} nm, defined ring width: $\pm${:.0f} nm\n".expandtabs().format(radius_fit,dR),xy=(0.05,annotate_y-0.02), xycoords = 'subfigure fraction',fontsize=14)
    plt.annotate("Percent of locs on ring: {:.1f}% \t\t Min. percent of locs on ring: {:.1f}%\n".expandtabs().format(perc_on_ring*100,perc_on_ring_min*100),xy=(0.05,annotate_y-0.04), xycoords = 'subfigure fraction',fontsize=14)
    plt.annotate("Percent of locs inside of ring: {:.1f}%  \t Max. percent of locs inside of ring: {:.1f}%\n".expandtabs().format(perc_inside_ring*100,perc_inside_ring_max*100),xy=(0.05,annotate_y-0.06), xycoords = 'subfigure fraction',fontsize=14)
    plt.annotate("Percent of locs outside of ring: {:.1f}% \t Max. percent of locs outside of ring: {:.1f}%\n".expandtabs().format(perc_outside_ring*100,perc_outside_ring_max*100),xy=(0.05,annotate_y-0.08), xycoords = 'subfigure fraction',fontsize=14)

    

    
    ## angle criterium
    ax_2 = fig.add_subplot(gs[0, 1], projection='polar')
    
    # segments
    ax_2.set_xticks(bins[1:]/180*np.pi)
    ax_2.set_thetalim(-np.pi,np.pi)
    #ax_2.tick_params(axis='x', width = 5, color = 'red')
    ax_2.xaxis.grid(linewidth=2, color = 'red')

    # filled ring segments
    for segment in perc_locs_per_segments_filled.index:
        coords_angle_segment = np.arange(segment.left/180*np.pi,segment.right/180*np.pi,0.01)
        ax_2.fill_between(coords_angle_segment,radius_min, radius_max, color='red', alpha=0.2)
       
    #ax_2.annotate(text = 'Hello', xy = (np.pi,500))
    for segment in perc_locs_per_segment.index:
        dangle = segment.right-segment.left
        angle_annotate = (segment.right-dangle/2)/180*np.pi
        ax_2.annotate(text = "{:.1f}%".format(perc_locs_per_segment[segment]*100),xy=(angle_annotate,radius_limit-50), ha='center', va='center')

    # locs
    ax_2.scatter(df_locs_not_ring['angle']/180*np.pi, df_locs_not_ring['radius'], alpha=0.1, c='#1f77b4')
    ax_2.scatter(df_locs_ring['angle']/180*np.pi, df_locs_ring['radius'], alpha=0.5, c='#1f77b4')

    # set maximum radius for plot such that 99% of locs are shown
    ax_2.set_rmax(radius_limit)
    
    ax_2.set_rlabel_position(2)

    ax_2.set_title('Localizations across {:.0f} segments\n\n\n\n\n'.format(N_segments), fontsize = 16)
    
    plt.annotate("Percentage of segments with more than {:.1f}% of the locs on the ring: {:.1f}% ".expandtabs().format(perc_locs_per_filled_segment_min*100,perc_segments_filled*100),xy=(0.55,annotate_y-0.02), xycoords = 'subfigure fraction',fontsize=14)
    plt.annotate("Min. percentage of segments with more than {:.1f}% of the locs on the ring: {:.1f}% ".expandtabs().format(perc_locs_per_filled_segment_min*100, perc_segments_filled_min*100),xy=(0.55,annotate_y-0.04), xycoords = 'subfigure fraction',fontsize=14)

    ################
    # Save result of criteria check in ring_data dataframe
    ################

        
    filename_base = 'fov_' + str(ring['fov_id']) +'_' + ring['cell_type'] +'_pick_' + str(ring['group'])
    filename_result =  filename_base +'_filter.png'
    if radius_criterium and angle_criterium:
        df_ring_data.loc[index,'filter_passed'] = 'Yes'
        fig.savefig(os.path.join(analysis_folder, filename_result), dpi=300, format="png")

    else:
        df_ring_data.loc[index,'filter_passed'] = 'No'
        fig.savefig(os.path.join(excluded_folder, filename_result), dpi=300, format="png")
        
        # Move fov_1_spor_pick_0.png file excluded_filter
        
        shutil.move(os.path.join(analysis_folder, filename_base + '.png'), os.path.join(excluded_folder, filename_base + '.png'))

        
df_ring_data = df_ring_data.drop(columns='filename_ring')



df_ring_data.to_csv(os.path.join(path,"ring_data_filter.csv"))
# Save dataframe with cell means for easy loading of data for postprocessing
df_ring_data.to_pickle(os.path.join(path,"ring_data_filter.pkl"))
# Out:
# fov_1_veg_pick_0_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.245919
# (-150.0, -120.0]    0.038085
# (-120.0, -90.0]     0.009793
# (-90.0, -60.0]      0.153428
# (-60.0, -30.0]      0.058760
# (-30.0, 0.0]        0.052231
# (0.0, 30.0]         0.063112
# (30.0, 60.0]        0.060936
# (60.0, 90.0]        0.045702
# (90.0, 120.0]       0.025027
# (120.0, 150.0]      0.114255
# (150.0, 180.0]      0.132753
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.245919
# (-150.0, -120.0]    0.038085
# (-90.0, -60.0]      0.153428
# (-60.0, -30.0]      0.058760
# (-30.0, 0.0]        0.052231
# (0.0, 30.0]         0.063112
# (30.0, 60.0]        0.060936
# (60.0, 90.0]        0.045702
# (90.0, 120.0]       0.025027
# (120.0, 150.0]      0.114255
# (150.0, 180.0]      0.132753
# Name: angle, dtype: float64
# fov_1_veg_pick_1_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.000000
# (-150.0, -120.0]    0.000000
# (-120.0, -90.0]     0.000000
# (-90.0, -60.0]      0.014717
# (-60.0, -30.0]      0.528330
# (-30.0, 0.0]        0.448124
# (0.0, 30.0]         0.003679
# (30.0, 60.0]        0.002943
# (60.0, 90.0]        0.000000
# (90.0, 120.0]       0.002208
# (120.0, 150.0]      0.000000
# (150.0, 180.0]      0.000000
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-60.0, -30.0]    0.528330
# (-30.0, 0.0]      0.448124
# Name: angle, dtype: float64
# fov_1_veg_pick_2_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.110028
# (-150.0, -120.0]    0.168524
# (-120.0, -90.0]     0.114206
# (-90.0, -60.0]      0.196379
# (-60.0, -30.0]      0.323120
# (-30.0, 0.0]        0.000000
# (0.0, 30.0]         0.036212
# (30.0, 60.0]        0.033426
# (60.0, 90.0]        0.002786
# (90.0, 120.0]       0.002786
# (120.0, 150.0]      0.012535
# (150.0, 180.0]      0.000000
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.110028
# (-150.0, -120.0]    0.168524
# (-120.0, -90.0]     0.114206
# (-90.0, -60.0]      0.196379
# (-60.0, -30.0]      0.323120
# (0.0, 30.0]         0.036212
# (30.0, 60.0]        0.033426
# Name: angle, dtype: float64
# fov_1_veg_pick_3_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.020661
# (-150.0, -120.0]    0.085950
# (-120.0, -90.0]     0.501653
# (-90.0, -60.0]      0.074380
# (-60.0, -30.0]      0.053719
# (-30.0, 0.0]        0.004132
# (0.0, 30.0]         0.168595
# (30.0, 60.0]        0.038843
# (60.0, 90.0]        0.000826
# (90.0, 120.0]       0.000000
# (120.0, 150.0]      0.004132
# (150.0, 180.0]      0.047107
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-150.0, -120.0]    0.085950
# (-120.0, -90.0]     0.501653
# (-90.0, -60.0]      0.074380
# (-60.0, -30.0]      0.053719
# (0.0, 30.0]         0.168595
# (30.0, 60.0]        0.038843
# (150.0, 180.0]      0.047107
# Name: angle, dtype: float64
# fov_1_veg_pick_4_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.313770
# (-150.0, -120.0]    0.340858
# (-120.0, -90.0]     0.209932
# (-90.0, -60.0]      0.000000
# (-60.0, -30.0]      0.103837
# (-30.0, 0.0]        0.004515
# (0.0, 30.0]         0.000000
# (30.0, 60.0]        0.009029
# (60.0, 90.0]        0.015801
# (90.0, 120.0]       0.000000
# (120.0, 150.0]      0.002257
# (150.0, 180.0]      0.000000
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.313770
# (-150.0, -120.0]    0.340858
# (-120.0, -90.0]     0.209932
# (-60.0, -30.0]      0.103837
# Name: angle, dtype: float64
# fov_2_veg_pick_0_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.264503
# (-150.0, -120.0]    0.068830
# (-120.0, -90.0]     0.108161
# (-90.0, -60.0]      0.072763
# (-60.0, -30.0]      0.062930
# (-30.0, 0.0]        0.145526
# (0.0, 30.0]         0.006883
# (30.0, 60.0]        0.016716
# (60.0, 90.0]        0.091445
# (90.0, 120.0]       0.007866
# (120.0, 150.0]      0.065880
# (150.0, 180.0]      0.088496
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.264503
# (-150.0, -120.0]    0.068830
# (-120.0, -90.0]     0.108161
# (-90.0, -60.0]      0.072763
# (-60.0, -30.0]      0.062930
# (-30.0, 0.0]        0.145526
# (60.0, 90.0]        0.091445
# (120.0, 150.0]      0.065880
# (150.0, 180.0]      0.088496
# Name: angle, dtype: float64
# fov_2_veg_pick_1_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.044925
# (-150.0, -120.0]    0.058236
# (-120.0, -90.0]     0.077371
# (-90.0, -60.0]      0.011647
# (-60.0, -30.0]      0.209651
# (-30.0, 0.0]        0.170549
# (0.0, 30.0]         0.097338
# (30.0, 60.0]        0.043261
# (60.0, 90.0]        0.021631
# (90.0, 120.0]       0.061564
# (120.0, 150.0]      0.059900
# (150.0, 180.0]      0.143927
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.044925
# (-150.0, -120.0]    0.058236
# (-120.0, -90.0]     0.077371
# (-60.0, -30.0]      0.209651
# (-30.0, 0.0]        0.170549
# (0.0, 30.0]         0.097338
# (30.0, 60.0]        0.043261
# (60.0, 90.0]        0.021631
# (90.0, 120.0]       0.061564
# (120.0, 150.0]      0.059900
# (150.0, 180.0]      0.143927
# Name: angle, dtype: float64
# fov_2_veg_pick_2_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.058423
# (-150.0, -120.0]    0.009737
# (-120.0, -90.0]     0.010711
# (-90.0, -60.0]      0.001947
# (-60.0, -30.0]      0.002921
# (-30.0, 0.0]        0.069133
# (0.0, 30.0]         0.189873
# (30.0, 60.0]        0.157741
# (60.0, 90.0]        0.096397
# (90.0, 120.0]       0.274586
# (120.0, 150.0]      0.014606
# (150.0, 180.0]      0.113924
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.058423
# (-30.0, 0.0]        0.069133
# (0.0, 30.0]         0.189873
# (30.0, 60.0]        0.157741
# (60.0, 90.0]        0.096397
# (90.0, 120.0]       0.274586
# (150.0, 180.0]      0.113924
# Name: angle, dtype: float64
# fov_2_veg_pick_3_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.110294
# (-150.0, -120.0]    0.171569
# (-120.0, -90.0]     0.145833
# (-90.0, -60.0]      0.007353
# (-60.0, -30.0]      0.056373
# (-30.0, 0.0]        0.083333
# (0.0, 30.0]         0.022059
# (30.0, 60.0]        0.001225
# (60.0, 90.0]        0.045343
# (90.0, 120.0]       0.113971
# (120.0, 150.0]      0.198529
# (150.0, 180.0]      0.044118
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.110294
# (-150.0, -120.0]    0.171569
# (-120.0, -90.0]     0.145833
# (-60.0, -30.0]      0.056373
# (-30.0, 0.0]        0.083333
# (0.0, 30.0]         0.022059
# (60.0, 90.0]        0.045343
# (90.0, 120.0]       0.113971
# (120.0, 150.0]      0.198529
# (150.0, 180.0]      0.044118
# Name: angle, dtype: float64
# fov_2_veg_pick_4_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.000000
# (-150.0, -120.0]    0.167899
# (-120.0, -90.0]     0.237592
# (-90.0, -60.0]      0.508976
# (-60.0, -30.0]      0.028511
# (-30.0, 0.0]        0.000000
# (0.0, 30.0]         0.000000
# (30.0, 60.0]        0.002112
# (60.0, 90.0]        0.000000
# (90.0, 120.0]       0.002112
# (120.0, 150.0]      0.048574
# (150.0, 180.0]      0.004224
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-150.0, -120.0]    0.167899
# (-120.0, -90.0]     0.237592
# (-90.0, -60.0]      0.508976
# (-60.0, -30.0]      0.028511
# (120.0, 150.0]      0.048574
# Name: angle, dtype: float64
# fov_2_veg_pick_5_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.318305
# (-150.0, -120.0]    0.101894
# (-120.0, -90.0]     0.044184
# (-90.0, -60.0]      0.092876
# (-60.0, -30.0]      0.099188
# (-30.0, 0.0]        0.018034
# (0.0, 30.0]         0.105500
# (30.0, 60.0]        0.032462
# (60.0, 90.0]        0.110009
# (90.0, 120.0]       0.026150
# (120.0, 150.0]      0.040577
# (150.0, 180.0]      0.010821
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.318305
# (-150.0, -120.0]    0.101894
# (-120.0, -90.0]     0.044184
# (-90.0, -60.0]      0.092876
# (-60.0, -30.0]      0.099188
# (0.0, 30.0]         0.105500
# (30.0, 60.0]        0.032462
# (60.0, 90.0]        0.110009
# (90.0, 120.0]       0.026150
# (120.0, 150.0]      0.040577
# Name: angle, dtype: float64
# fov_3_veg_pick_0_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.074576
# (-150.0, -120.0]    0.047458
# (-120.0, -90.0]     0.010169
# (-90.0, -60.0]      0.006780
# (-60.0, -30.0]      0.040678
# (-30.0, 0.0]        0.037288
# (0.0, 30.0]         0.067797
# (30.0, 60.0]        0.030508
# (60.0, 90.0]        0.013559
# (90.0, 120.0]       0.254237
# (120.0, 150.0]      0.091525
# (150.0, 180.0]      0.325424
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.074576
# (-150.0, -120.0]    0.047458
# (-60.0, -30.0]      0.040678
# (-30.0, 0.0]        0.037288
# (0.0, 30.0]         0.067797
# (30.0, 60.0]        0.030508
# (90.0, 120.0]       0.254237
# (120.0, 150.0]      0.091525
# (150.0, 180.0]      0.325424
# Name: angle, dtype: float64
# fov_3_veg_pick_1_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.191724
# (-150.0, -120.0]    0.110345
# (-120.0, -90.0]     0.013793
# (-90.0, -60.0]      0.008276
# (-60.0, -30.0]      0.012414
# (-30.0, 0.0]        0.095172
# (0.0, 30.0]         0.030345
# (30.0, 60.0]        0.051034
# (60.0, 90.0]        0.000000
# (90.0, 120.0]       0.099310
# (120.0, 150.0]      0.092414
# (150.0, 180.0]      0.295172
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.191724
# (-150.0, -120.0]    0.110345
# (-30.0, 0.0]        0.095172
# (0.0, 30.0]         0.030345
# (30.0, 60.0]        0.051034
# (90.0, 120.0]       0.099310
# (120.0, 150.0]      0.092414
# (150.0, 180.0]      0.295172
# Name: angle, dtype: float64
# fov_3_veg_pick_2_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.303644
# (-150.0, -120.0]    0.161943
# (-120.0, -90.0]     0.072874
# (-90.0, -60.0]      0.004049
# (-60.0, -30.0]      0.129555
# (-30.0, 0.0]        0.076923
# (0.0, 30.0]         0.178138
# (30.0, 60.0]        0.000000
# (60.0, 90.0]        0.000000
# (90.0, 120.0]       0.000000
# (120.0, 150.0]      0.000000
# (150.0, 180.0]      0.072874
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.303644
# (-150.0, -120.0]    0.161943
# (-120.0, -90.0]     0.072874
# (-60.0, -30.0]      0.129555
# (-30.0, 0.0]        0.076923
# (0.0, 30.0]         0.178138
# (150.0, 180.0]      0.072874
# Name: angle, dtype: float64
# fov_3_veg_pick_3_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.255144
# (-150.0, -120.0]    0.016461
# (-120.0, -90.0]     0.004115
# (-90.0, -60.0]      0.222222
# (-60.0, -30.0]      0.057613
# (-30.0, 0.0]        0.028807
# (0.0, 30.0]         0.000000
# (30.0, 60.0]        0.053498
# (60.0, 90.0]        0.012346
# (90.0, 120.0]       0.024691
# (120.0, 150.0]      0.242798
# (150.0, 180.0]      0.082305
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.255144
# (-90.0, -60.0]      0.222222
# (-60.0, -30.0]      0.057613
# (-30.0, 0.0]        0.028807
# (30.0, 60.0]        0.053498
# (90.0, 120.0]       0.024691
# (120.0, 150.0]      0.242798
# (150.0, 180.0]      0.082305
# Name: angle, dtype: float64
# fov_3_veg_pick_4_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.000000
# (-150.0, -120.0]    0.000000
# (-120.0, -90.0]     0.016736
# (-90.0, -60.0]      0.008368
# (-60.0, -30.0]      0.025105
# (-30.0, 0.0]        0.033473
# (0.0, 30.0]         0.334728
# (30.0, 60.0]        0.410042
# (60.0, 90.0]        0.171548
# (90.0, 120.0]       0.000000
# (120.0, 150.0]      0.000000
# (150.0, 180.0]      0.000000
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-60.0, -30.0]    0.025105
# (-30.0, 0.0]      0.033473
# (0.0, 30.0]       0.334728
# (30.0, 60.0]      0.410042
# (60.0, 90.0]      0.171548
# Name: angle, dtype: float64
# fov_4_veg_pick_0_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.117914
# (-150.0, -120.0]    0.006803
# (-120.0, -90.0]     0.018141
# (-90.0, -60.0]      0.079365
# (-60.0, -30.0]      0.145125
# (-30.0, 0.0]        0.004535
# (0.0, 30.0]         0.170068
# (30.0, 60.0]        0.081633
# (60.0, 90.0]        0.049887
# (90.0, 120.0]       0.097506
# (120.0, 150.0]      0.147392
# (150.0, 180.0]      0.081633
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.117914
# (-90.0, -60.0]      0.079365
# (-60.0, -30.0]      0.145125
# (0.0, 30.0]         0.170068
# (30.0, 60.0]        0.081633
# (60.0, 90.0]        0.049887
# (90.0, 120.0]       0.097506
# (120.0, 150.0]      0.147392
# (150.0, 180.0]      0.081633
# Name: angle, dtype: float64
# fov_4_veg_pick_1_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.079780
# (-150.0, -120.0]    0.088033
# (-120.0, -90.0]     0.103164
# (-90.0, -60.0]      0.057772
# (-60.0, -30.0]      0.060523
# (-30.0, 0.0]        0.115543
# (0.0, 30.0]         0.122421
# (30.0, 60.0]        0.013755
# (60.0, 90.0]        0.000000
# (90.0, 120.0]       0.000000
# (120.0, 150.0]      0.037139
# (150.0, 180.0]      0.321871
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.079780
# (-150.0, -120.0]    0.088033
# (-120.0, -90.0]     0.103164
# (-90.0, -60.0]      0.057772
# (-60.0, -30.0]      0.060523
# (-30.0, 0.0]        0.115543
# (0.0, 30.0]         0.122421
# (120.0, 150.0]      0.037139
# (150.0, 180.0]      0.321871
# Name: angle, dtype: float64
# fov_4_veg_pick_2_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.152866
# (-150.0, -120.0]    0.000000
# (-120.0, -90.0]     0.076433
# (-90.0, -60.0]      0.000000
# (-60.0, -30.0]      0.118896
# (-30.0, 0.0]        0.231423
# (0.0, 30.0]         0.048832
# (30.0, 60.0]        0.061571
# (60.0, 90.0]        0.070064
# (90.0, 120.0]       0.055202
# (120.0, 150.0]      0.067941
# (150.0, 180.0]      0.116773
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.152866
# (-120.0, -90.0]     0.076433
# (-60.0, -30.0]      0.118896
# (-30.0, 0.0]        0.231423
# (0.0, 30.0]         0.048832
# (30.0, 60.0]        0.061571
# (60.0, 90.0]        0.070064
# (90.0, 120.0]       0.055202
# (120.0, 150.0]      0.067941
# (150.0, 180.0]      0.116773
# Name: angle, dtype: float64
# fov_4_veg_pick_3_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.030769
# (-150.0, -120.0]    0.073846
# (-120.0, -90.0]     0.000000
# (-90.0, -60.0]      0.076923
# (-60.0, -30.0]      0.073846
# (-30.0, 0.0]        0.015385
# (0.0, 30.0]         0.369231
# (30.0, 60.0]        0.046154
# (60.0, 90.0]        0.000000
# (90.0, 120.0]       0.036923
# (120.0, 150.0]      0.236923
# (150.0, 180.0]      0.040000
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.030769
# (-150.0, -120.0]    0.073846
# (-90.0, -60.0]      0.076923
# (-60.0, -30.0]      0.073846
# (0.0, 30.0]         0.369231
# (30.0, 60.0]        0.046154
# (90.0, 120.0]       0.036923
# (120.0, 150.0]      0.236923
# (150.0, 180.0]      0.040000
# Name: angle, dtype: float64
# fov_5_spor_pick_0_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.052685
# (-150.0, -120.0]    0.012158
# (-120.0, -90.0]     0.002026
# (-90.0, -60.0]      0.000000
# (-60.0, -30.0]      0.000000
# (-30.0, 0.0]        0.005066
# (0.0, 30.0]         0.046606
# (30.0, 60.0]        0.112462
# (60.0, 90.0]        0.173252
# (90.0, 120.0]       0.061803
# (120.0, 150.0]      0.454914
# (150.0, 180.0]      0.079027
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.052685
# (0.0, 30.0]         0.046606
# (30.0, 60.0]        0.112462
# (60.0, 90.0]        0.173252
# (90.0, 120.0]       0.061803
# (120.0, 150.0]      0.454914
# (150.0, 180.0]      0.079027
# Name: angle, dtype: float64
# fov_5_spor_pick_1_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.090250
# (-150.0, -120.0]    0.240935
# (-120.0, -90.0]     0.161160
# (-90.0, -60.0]      0.093473
# (-60.0, -30.0]      0.185334
# (-30.0, 0.0]        0.059629
# (0.0, 30.0]         0.060435
# (30.0, 60.0]        0.004029
# (60.0, 90.0]        0.001612
# (90.0, 120.0]       0.001612
# (120.0, 150.0]      0.004029
# (150.0, 180.0]      0.097502
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.090250
# (-150.0, -120.0]    0.240935
# (-120.0, -90.0]     0.161160
# (-90.0, -60.0]      0.093473
# (-60.0, -30.0]      0.185334
# (-30.0, 0.0]        0.059629
# (0.0, 30.0]         0.060435
# (150.0, 180.0]      0.097502
# Name: angle, dtype: float64
# fov_5_spor_pick_2_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.000000
# (-150.0, -120.0]    0.006696
# (-120.0, -90.0]     0.348214
# (-90.0, -60.0]      0.252232
# (-60.0, -30.0]      0.354911
# (-30.0, 0.0]        0.004464
# (0.0, 30.0]         0.022321
# (30.0, 60.0]        0.002232
# (60.0, 90.0]        0.002232
# (90.0, 120.0]       0.000000
# (120.0, 150.0]      0.006696
# (150.0, 180.0]      0.000000
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-120.0, -90.0]    0.348214
# (-90.0, -60.0]     0.252232
# (-60.0, -30.0]     0.354911
# (0.0, 30.0]        0.022321
# Name: angle, dtype: float64
# fov_5_spor_pick_3_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.066167
# (-150.0, -120.0]    0.079900
# (-120.0, -90.0]     0.147316
# (-90.0, -60.0]      0.004994
# (-60.0, -30.0]      0.006242
# (-30.0, 0.0]        0.275905
# (0.0, 30.0]         0.191011
# (30.0, 60.0]        0.028714
# (60.0, 90.0]        0.003745
# (90.0, 120.0]       0.087391
# (120.0, 150.0]      0.102372
# (150.0, 180.0]      0.006242
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.066167
# (-150.0, -120.0]    0.079900
# (-120.0, -90.0]     0.147316
# (-30.0, 0.0]        0.275905
# (0.0, 30.0]         0.191011
# (30.0, 60.0]        0.028714
# (90.0, 120.0]       0.087391
# (120.0, 150.0]      0.102372
# Name: angle, dtype: float64
# fov_5_spor_pick_4_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.317156
# (-150.0, -120.0]    0.161400
# (-120.0, -90.0]     0.020316
# (-90.0, -60.0]      0.051919
# (-60.0, -30.0]      0.058691
# (-30.0, 0.0]        0.102709
# (0.0, 30.0]         0.084650
# (30.0, 60.0]        0.037246
# (60.0, 90.0]        0.011287
# (90.0, 120.0]       0.005643
# (120.0, 150.0]      0.020316
# (150.0, 180.0]      0.128668
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.317156
# (-150.0, -120.0]    0.161400
# (-90.0, -60.0]      0.051919
# (-60.0, -30.0]      0.058691
# (-30.0, 0.0]        0.102709
# (0.0, 30.0]         0.084650
# (30.0, 60.0]        0.037246
# (150.0, 180.0]      0.128668
# Name: angle, dtype: float64
# fov_5_spor_pick_5_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.028723
# (-150.0, -120.0]    0.293617
# (-120.0, -90.0]     0.064894
# (-90.0, -60.0]      0.158511
# (-60.0, -30.0]      0.127660
# (-30.0, 0.0]        0.057447
# (0.0, 30.0]         0.165957
# (30.0, 60.0]        0.010638
# (60.0, 90.0]        0.001064
# (90.0, 120.0]       0.005319
# (120.0, 150.0]      0.007447
# (150.0, 180.0]      0.078723
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.028723
# (-150.0, -120.0]    0.293617
# (-120.0, -90.0]     0.064894
# (-90.0, -60.0]      0.158511
# (-60.0, -30.0]      0.127660
# (-30.0, 0.0]        0.057447
# (0.0, 30.0]         0.165957
# (150.0, 180.0]      0.078723
# Name: angle, dtype: float64
# fov_5_spor_pick_6_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.000000
# (-150.0, -120.0]    0.014344
# (-120.0, -90.0]     0.352459
# (-90.0, -60.0]      0.600410
# (-60.0, -30.0]      0.026639
# (-30.0, 0.0]        0.000000
# (0.0, 30.0]         0.000000
# (30.0, 60.0]        0.002049
# (60.0, 90.0]        0.000000
# (90.0, 120.0]       0.000000
# (120.0, 150.0]      0.002049
# (150.0, 180.0]      0.002049
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-120.0, -90.0]    0.352459
# (-90.0, -60.0]     0.600410
# (-60.0, -30.0]     0.026639
# Name: angle, dtype: float64
# fov_5_spor_pick_7_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.179598
# (-150.0, -120.0]    0.099138
# (-120.0, -90.0]     0.373563
# (-90.0, -60.0]      0.158046
# (-60.0, -30.0]      0.001437
# (-30.0, 0.0]        0.000000
# (0.0, 30.0]         0.001437
# (30.0, 60.0]        0.012931
# (60.0, 90.0]        0.165230
# (90.0, 120.0]       0.001437
# (120.0, 150.0]      0.007184
# (150.0, 180.0]      0.000000
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.179598
# (-150.0, -120.0]    0.099138
# (-120.0, -90.0]     0.373563
# (-90.0, -60.0]      0.158046
# (60.0, 90.0]        0.165230
# Name: angle, dtype: float64
# fov_5_spor_pick_8_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.184158
# (-150.0, -120.0]    0.009901
# (-120.0, -90.0]     0.022772
# (-90.0, -60.0]      0.023762
# (-60.0, -30.0]      0.124752
# (-30.0, 0.0]        0.054455
# (0.0, 30.0]         0.008911
# (30.0, 60.0]        0.100000
# (60.0, 90.0]        0.132673
# (90.0, 120.0]       0.106931
# (120.0, 150.0]      0.035644
# (150.0, 180.0]      0.196040
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.184158
# (-120.0, -90.0]     0.022772
# (-90.0, -60.0]      0.023762
# (-60.0, -30.0]      0.124752
# (-30.0, 0.0]        0.054455
# (30.0, 60.0]        0.100000
# (60.0, 90.0]        0.132673
# (90.0, 120.0]       0.106931
# (120.0, 150.0]      0.035644
# (150.0, 180.0]      0.196040
# Name: angle, dtype: float64
# fov_5_spor_pick_9_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.000000
# (-150.0, -120.0]    0.000000
# (-120.0, -90.0]     0.261954
# (-90.0, -60.0]      0.353430
# (-60.0, -30.0]      0.257796
# (-30.0, 0.0]        0.081081
# (0.0, 30.0]         0.000000
# (30.0, 60.0]        0.002079
# (60.0, 90.0]        0.004158
# (90.0, 120.0]       0.004158
# (120.0, 150.0]      0.035343
# (150.0, 180.0]      0.000000
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-120.0, -90.0]    0.261954
# (-90.0, -60.0]     0.353430
# (-60.0, -30.0]     0.257796
# (-30.0, 0.0]       0.081081
# (120.0, 150.0]     0.035343
# Name: angle, dtype: float64
# fov_5_spor_pick_10_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.336976
# (-150.0, -120.0]    0.040073
# (-120.0, -90.0]     0.000000
# (-90.0, -60.0]      0.003643
# (-60.0, -30.0]      0.003643
# (-30.0, 0.0]        0.134791
# (0.0, 30.0]         0.001821
# (30.0, 60.0]        0.001821
# (60.0, 90.0]        0.089253
# (90.0, 120.0]       0.109290
# (120.0, 150.0]      0.225865
# (150.0, 180.0]      0.052823
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.336976
# (-150.0, -120.0]    0.040073
# (-30.0, 0.0]        0.134791
# (60.0, 90.0]        0.089253
# (90.0, 120.0]       0.109290
# (120.0, 150.0]      0.225865
# (150.0, 180.0]      0.052823
# Name: angle, dtype: float64
# fov_1_spor_pick_0_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.000000
# (-150.0, -120.0]    0.000000
# (-120.0, -90.0]     0.000000
# (-90.0, -60.0]      0.000000
# (-60.0, -30.0]      0.000000
# (-30.0, 0.0]        0.010309
# (0.0, 30.0]         0.280069
# (30.0, 60.0]        0.079038
# (60.0, 90.0]        0.269759
# (90.0, 120.0]       0.360825
# (120.0, 150.0]      0.000000
# (150.0, 180.0]      0.000000
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (0.0, 30.0]      0.280069
# (30.0, 60.0]     0.079038
# (60.0, 90.0]     0.269759
# (90.0, 120.0]    0.360825
# Name: angle, dtype: float64
# fov_1_spor_pick_1_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.030441
# (-150.0, -120.0]    0.000000
# (-120.0, -90.0]     0.000000
# (-90.0, -60.0]      0.001522
# (-60.0, -30.0]      0.001522
# (-30.0, 0.0]        0.028919
# (0.0, 30.0]         0.280061
# (30.0, 60.0]        0.010654
# (60.0, 90.0]        0.097412
# (90.0, 120.0]       0.234399
# (120.0, 150.0]      0.083714
# (150.0, 180.0]      0.231355
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.030441
# (-30.0, 0.0]        0.028919
# (0.0, 30.0]         0.280061
# (60.0, 90.0]        0.097412
# (90.0, 120.0]       0.234399
# (120.0, 150.0]      0.083714
# (150.0, 180.0]      0.231355
# Name: angle, dtype: float64
# fov_1_spor_pick_2_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.170240
# (-150.0, -120.0]    0.181589
# (-120.0, -90.0]     0.080706
# (-90.0, -60.0]      0.177806
# (-60.0, -30.0]      0.114754
# (-30.0, 0.0]        0.240858
# (0.0, 30.0]         0.002522
# (30.0, 60.0]        0.010088
# (60.0, 90.0]        0.018916
# (90.0, 120.0]       0.000000
# (120.0, 150.0]      0.000000
# (150.0, 180.0]      0.002522
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.170240
# (-150.0, -120.0]    0.181589
# (-120.0, -90.0]     0.080706
# (-90.0, -60.0]      0.177806
# (-60.0, -30.0]      0.114754
# (-30.0, 0.0]        0.240858
# Name: angle, dtype: float64
# fov_1_spor_pick_3_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.001252
# (-150.0, -120.0]    0.078849
# (-120.0, -90.0]     0.080100
# (-90.0, -60.0]      0.033792
# (-60.0, -30.0]      0.205257
# (-30.0, 0.0]        0.130163
# (0.0, 30.0]         0.123905
# (30.0, 60.0]        0.133917
# (60.0, 90.0]        0.141427
# (90.0, 120.0]       0.055069
# (120.0, 150.0]      0.015019
# (150.0, 180.0]      0.001252
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-150.0, -120.0]    0.078849
# (-120.0, -90.0]     0.080100
# (-90.0, -60.0]      0.033792
# (-60.0, -30.0]      0.205257
# (-30.0, 0.0]        0.130163
# (0.0, 30.0]         0.123905
# (30.0, 60.0]        0.133917
# (60.0, 90.0]        0.141427
# (90.0, 120.0]       0.055069
# Name: angle, dtype: float64
# fov_1_spor_pick_4_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.267025
# (-150.0, -120.0]    0.240143
# (-120.0, -90.0]     0.044803
# (-90.0, -60.0]      0.014337
# (-60.0, -30.0]      0.229391
# (-30.0, 0.0]        0.141577
# (0.0, 30.0]         0.046595
# (30.0, 60.0]        0.001792
# (60.0, 90.0]        0.012545
# (90.0, 120.0]       0.001792
# (120.0, 150.0]      0.000000
# (150.0, 180.0]      0.000000
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.267025
# (-150.0, -120.0]    0.240143
# (-120.0, -90.0]     0.044803
# (-60.0, -30.0]      0.229391
# (-30.0, 0.0]        0.141577
# (0.0, 30.0]         0.046595
# Name: angle, dtype: float64
# fov_1_spor_pick_5_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.182254
# (-150.0, -120.0]    0.085132
# (-120.0, -90.0]     0.100719
# (-90.0, -60.0]      0.043165
# (-60.0, -30.0]      0.249400
# (-30.0, 0.0]        0.213429
# (0.0, 30.0]         0.025180
# (30.0, 60.0]        0.013189
# (60.0, 90.0]        0.065947
# (90.0, 120.0]       0.013189
# (120.0, 150.0]      0.003597
# (150.0, 180.0]      0.004796
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.182254
# (-150.0, -120.0]    0.085132
# (-120.0, -90.0]     0.100719
# (-90.0, -60.0]      0.043165
# (-60.0, -30.0]      0.249400
# (-30.0, 0.0]        0.213429
# (0.0, 30.0]         0.025180
# (60.0, 90.0]        0.065947
# Name: angle, dtype: float64
# fov_1_spor_pick_6_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.000000
# (-150.0, -120.0]    0.000000
# (-120.0, -90.0]     0.000000
# (-90.0, -60.0]      0.001451
# (-60.0, -30.0]      0.002903
# (-30.0, 0.0]        0.000000
# (0.0, 30.0]         0.547170
# (30.0, 60.0]        0.448476
# (60.0, 90.0]        0.000000
# (90.0, 120.0]       0.000000
# (120.0, 150.0]      0.000000
# (150.0, 180.0]      0.000000
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (0.0, 30.0]     0.547170
# (30.0, 60.0]    0.448476
# Name: angle, dtype: float64
# fov_1_spor_pick_7_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.230441
# (-150.0, -120.0]    0.027027
# (-120.0, -90.0]     0.229018
# (-90.0, -60.0]      0.182077
# (-60.0, -30.0]      0.105263
# (-30.0, 0.0]        0.082504
# (0.0, 30.0]         0.079659
# (30.0, 60.0]        0.062589
# (60.0, 90.0]        0.001422
# (90.0, 120.0]       0.000000
# (120.0, 150.0]      0.000000
# (150.0, 180.0]      0.000000
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.230441
# (-150.0, -120.0]    0.027027
# (-120.0, -90.0]     0.229018
# (-90.0, -60.0]      0.182077
# (-60.0, -30.0]      0.105263
# (-30.0, 0.0]        0.082504
# (0.0, 30.0]         0.079659
# (30.0, 60.0]        0.062589
# Name: angle, dtype: float64
# fov_1_spor_pick_8_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.056166
# (-150.0, -120.0]    0.009768
# (-120.0, -90.0]     0.032967
# (-90.0, -60.0]      0.252747
# (-60.0, -30.0]      0.179487
# (-30.0, 0.0]        0.139194
# (0.0, 30.0]         0.150183
# (30.0, 60.0]        0.043956
# (60.0, 90.0]        0.007326
# (90.0, 120.0]       0.042735
# (120.0, 150.0]      0.041514
# (150.0, 180.0]      0.043956
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.056166
# (-120.0, -90.0]     0.032967
# (-90.0, -60.0]      0.252747
# (-60.0, -30.0]      0.179487
# (-30.0, 0.0]        0.139194
# (0.0, 30.0]         0.150183
# (30.0, 60.0]        0.043956
# (90.0, 120.0]       0.042735
# (120.0, 150.0]      0.041514
# (150.0, 180.0]      0.043956
# Name: angle, dtype: float64
# fov_1_spor_pick_9_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.099813
# (-150.0, -120.0]    0.051306
# (-120.0, -90.0]     0.014925
# (-90.0, -60.0]      0.010261
# (-60.0, -30.0]      0.318097
# (-30.0, 0.0]        0.072761
# (0.0, 30.0]         0.078358
# (30.0, 60.0]        0.079291
# (60.0, 90.0]        0.037313
# (90.0, 120.0]       0.073694
# (120.0, 150.0]      0.153918
# (150.0, 180.0]      0.010261
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.099813
# (-150.0, -120.0]    0.051306
# (-60.0, -30.0]      0.318097
# (-30.0, 0.0]        0.072761
# (0.0, 30.0]         0.078358
# (30.0, 60.0]        0.079291
# (60.0, 90.0]        0.037313
# (90.0, 120.0]       0.073694
# (120.0, 150.0]      0.153918
# Name: angle, dtype: float64
# fov_1_spor_pick_10_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.207076
# (-150.0, -120.0]    0.063476
# (-120.0, -90.0]     0.009365
# (-90.0, -60.0]      0.041623
# (-60.0, -30.0]      0.069719
# (-30.0, 0.0]        0.161290
# (0.0, 30.0]         0.059313
# (30.0, 60.0]        0.012487
# (60.0, 90.0]        0.089490
# (90.0, 120.0]       0.037461
# (120.0, 150.0]      0.215401
# (150.0, 180.0]      0.033299
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.207076
# (-150.0, -120.0]    0.063476
# (-90.0, -60.0]      0.041623
# (-60.0, -30.0]      0.069719
# (-30.0, 0.0]        0.161290
# (0.0, 30.0]         0.059313
# (60.0, 90.0]        0.089490
# (90.0, 120.0]       0.037461
# (120.0, 150.0]      0.215401
# (150.0, 180.0]      0.033299
# Name: angle, dtype: float64
# fov_1_spor_pick_11_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.083604
# (-150.0, -120.0]    0.099026
# (-120.0, -90.0]     0.133929
# (-90.0, -60.0]      0.074675
# (-60.0, -30.0]      0.110390
# (-30.0, 0.0]        0.001623
# (0.0, 30.0]         0.125000
# (30.0, 60.0]        0.083604
# (60.0, 90.0]        0.271104
# (90.0, 120.0]       0.008117
# (120.0, 150.0]      0.000812
# (150.0, 180.0]      0.008117
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.083604
# (-150.0, -120.0]    0.099026
# (-120.0, -90.0]     0.133929
# (-90.0, -60.0]      0.074675
# (-60.0, -30.0]      0.110390
# (0.0, 30.0]         0.125000
# (30.0, 60.0]        0.083604
# (60.0, 90.0]        0.271104
# Name: angle, dtype: float64
# fov_1_spor_pick_12_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.198330
# (-150.0, -120.0]    0.173278
# (-120.0, -90.0]     0.129436
# (-90.0, -60.0]      0.014614
# (-60.0, -30.0]      0.129436
# (-30.0, 0.0]        0.118998
# (0.0, 30.0]         0.041754
# (30.0, 60.0]        0.018789
# (60.0, 90.0]        0.002088
# (90.0, 120.0]       0.058455
# (120.0, 150.0]      0.104384
# (150.0, 180.0]      0.010438
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.198330
# (-150.0, -120.0]    0.173278
# (-120.0, -90.0]     0.129436
# (-60.0, -30.0]      0.129436
# (-30.0, 0.0]        0.118998
# (0.0, 30.0]         0.041754
# (90.0, 120.0]       0.058455
# (120.0, 150.0]      0.104384
# Name: angle, dtype: float64
# fov_1_spor_pick_13_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.032425
# (-150.0, -120.0]    0.182879
# (-120.0, -90.0]     0.007782
# (-90.0, -60.0]      0.000000
# (-60.0, -30.0]      0.070039
# (-30.0, 0.0]        0.306096
# (0.0, 30.0]         0.175097
# (30.0, 60.0]        0.120623
# (60.0, 90.0]        0.041505
# (90.0, 120.0]       0.032425
# (120.0, 150.0]      0.012970
# (150.0, 180.0]      0.018158
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.032425
# (-150.0, -120.0]    0.182879
# (-60.0, -30.0]      0.070039
# (-30.0, 0.0]        0.306096
# (0.0, 30.0]         0.175097
# (30.0, 60.0]        0.120623
# (60.0, 90.0]        0.041505
# (90.0, 120.0]       0.032425
# Name: angle, dtype: float64
# fov_5_veg_pick_0_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.000738
# (-150.0, -120.0]    0.000000
# (-120.0, -90.0]     0.000000
# (-90.0, -60.0]      0.000000
# (-60.0, -30.0]      0.000000
# (-30.0, 0.0]        0.001476
# (0.0, 30.0]         0.000738
# (30.0, 60.0]        0.004428
# (60.0, 90.0]        0.147601
# (90.0, 120.0]       0.744649
# (120.0, 150.0]      0.095941
# (150.0, 180.0]      0.004428
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (60.0, 90.0]      0.147601
# (90.0, 120.0]     0.744649
# (120.0, 150.0]    0.095941
# Name: angle, dtype: float64
# fov_5_veg_pick_1_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.182663
# (-150.0, -120.0]    0.115583
# (-120.0, -90.0]     0.105263
# (-90.0, -60.0]      0.242518
# (-60.0, -30.0]      0.106295
# (-30.0, 0.0]        0.089783
# (0.0, 30.0]         0.045408
# (30.0, 60.0]        0.048504
# (60.0, 90.0]        0.027864
# (90.0, 120.0]       0.022704
# (120.0, 150.0]      0.002064
# (150.0, 180.0]      0.011352
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.182663
# (-150.0, -120.0]    0.115583
# (-120.0, -90.0]     0.105263
# (-90.0, -60.0]      0.242518
# (-60.0, -30.0]      0.106295
# (-30.0, 0.0]        0.089783
# (0.0, 30.0]         0.045408
# (30.0, 60.0]        0.048504
# (60.0, 90.0]        0.027864
# (90.0, 120.0]       0.022704
# Name: angle, dtype: float64
# fov_5_veg_pick_2_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.098765
# (-150.0, -120.0]    0.007597
# (-120.0, -90.0]     0.000000
# (-90.0, -60.0]      0.000000
# (-60.0, -30.0]      0.008547
# (-30.0, 0.0]        0.263058
# (0.0, 30.0]         0.283951
# (30.0, 60.0]        0.080722
# (60.0, 90.0]        0.079772
# (90.0, 120.0]       0.055081
# (120.0, 150.0]      0.048433
# (150.0, 180.0]      0.074074
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.098765
# (-30.0, 0.0]        0.263058
# (0.0, 30.0]         0.283951
# (30.0, 60.0]        0.080722
# (60.0, 90.0]        0.079772
# (90.0, 120.0]       0.055081
# (120.0, 150.0]      0.048433
# (150.0, 180.0]      0.074074
# Name: angle, dtype: float64
# fov_5_veg_pick_3_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.126733
# (-150.0, -120.0]    0.054125
# (-120.0, -90.0]     0.139274
# (-90.0, -60.0]      0.157756
# (-60.0, -30.0]      0.013861
# (-30.0, 0.0]        0.016502
# (0.0, 30.0]         0.025083
# (30.0, 60.0]        0.014521
# (60.0, 90.0]        0.032343
# (90.0, 120.0]       0.075248
# (120.0, 150.0]      0.070627
# (150.0, 180.0]      0.273927
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.126733
# (-150.0, -120.0]    0.054125
# (-120.0, -90.0]     0.139274
# (-90.0, -60.0]      0.157756
# (0.0, 30.0]         0.025083
# (60.0, 90.0]        0.032343
# (90.0, 120.0]       0.075248
# (120.0, 150.0]      0.070627
# (150.0, 180.0]      0.273927
# Name: angle, dtype: float64
# fov_6_spor_pick_0_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.037443
# (-150.0, -120.0]    0.527854
# (-120.0, -90.0]     0.230137
# (-90.0, -60.0]      0.162557
# (-60.0, -30.0]      0.005479
# (-30.0, 0.0]        0.000000
# (0.0, 30.0]         0.007306
# (30.0, 60.0]        0.000913
# (60.0, 90.0]        0.007306
# (90.0, 120.0]       0.003653
# (120.0, 150.0]      0.001826
# (150.0, 180.0]      0.015525
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.037443
# (-150.0, -120.0]    0.527854
# (-120.0, -90.0]     0.230137
# (-90.0, -60.0]      0.162557
# Name: angle, dtype: float64
# fov_6_spor_pick_1_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.068146
# (-150.0, -120.0]    0.185420
# (-120.0, -90.0]     0.012678
# (-90.0, -60.0]      0.145800
# (-60.0, -30.0]      0.215531
# (-30.0, 0.0]        0.139461
# (0.0, 30.0]         0.210777
# (30.0, 60.0]        0.009509
# (60.0, 90.0]        0.000000
# (90.0, 120.0]       0.000000
# (120.0, 150.0]      0.000000
# (150.0, 180.0]      0.012678
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.068146
# (-150.0, -120.0]    0.185420
# (-90.0, -60.0]      0.145800
# (-60.0, -30.0]      0.215531
# (-30.0, 0.0]        0.139461
# (0.0, 30.0]         0.210777
# Name: angle, dtype: float64
# fov_6_spor_pick_2_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.079787
# (-150.0, -120.0]    0.064894
# (-120.0, -90.0]     0.025532
# (-90.0, -60.0]      0.064894
# (-60.0, -30.0]      0.042553
# (-30.0, 0.0]        0.240426
# (0.0, 30.0]         0.000000
# (30.0, 60.0]        0.091489
# (60.0, 90.0]        0.063830
# (90.0, 120.0]       0.021277
# (120.0, 150.0]      0.253191
# (150.0, 180.0]      0.052128
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.079787
# (-150.0, -120.0]    0.064894
# (-120.0, -90.0]     0.025532
# (-90.0, -60.0]      0.064894
# (-60.0, -30.0]      0.042553
# (-30.0, 0.0]        0.240426
# (30.0, 60.0]        0.091489
# (60.0, 90.0]        0.063830
# (90.0, 120.0]       0.021277
# (120.0, 150.0]      0.253191
# (150.0, 180.0]      0.052128
# Name: angle, dtype: float64
# fov_6_spor_pick_3_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.220096
# (-150.0, -120.0]    0.294258
# (-120.0, -90.0]     0.050239
# (-90.0, -60.0]      0.047847
# (-60.0, -30.0]      0.028708
# (-30.0, 0.0]        0.138756
# (0.0, 30.0]         0.035885
# (30.0, 60.0]        0.026316
# (60.0, 90.0]        0.112440
# (90.0, 120.0]       0.000000
# (120.0, 150.0]      0.021531
# (150.0, 180.0]      0.023923
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.220096
# (-150.0, -120.0]    0.294258
# (-120.0, -90.0]     0.050239
# (-90.0, -60.0]      0.047847
# (-60.0, -30.0]      0.028708
# (-30.0, 0.0]        0.138756
# (0.0, 30.0]         0.035885
# (30.0, 60.0]        0.026316
# (60.0, 90.0]        0.112440
# (120.0, 150.0]      0.021531
# (150.0, 180.0]      0.023923
# Name: angle, dtype: float64
# fov_6_spor_pick_4_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.375848
# (-150.0, -120.0]    0.002714
# (-120.0, -90.0]     0.000000
# (-90.0, -60.0]      0.000000
# (-60.0, -30.0]      0.000000
# (-30.0, 0.0]        0.000000
# (0.0, 30.0]         0.062415
# (30.0, 60.0]        0.324288
# (60.0, 90.0]        0.085482
# (90.0, 120.0]       0.027137
# (120.0, 150.0]      0.002714
# (150.0, 180.0]      0.119403
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.375848
# (0.0, 30.0]         0.062415
# (30.0, 60.0]        0.324288
# (60.0, 90.0]        0.085482
# (90.0, 120.0]       0.027137
# (150.0, 180.0]      0.119403
# Name: angle, dtype: float64
# fov_6_spor_pick_5_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.041304
# (-150.0, -120.0]    0.219565
# (-120.0, -90.0]     0.019565
# (-90.0, -60.0]      0.004348
# (-60.0, -30.0]      0.002174
# (-30.0, 0.0]        0.006522
# (0.0, 30.0]         0.002174
# (30.0, 60.0]        0.000000
# (60.0, 90.0]        0.121739
# (90.0, 120.0]       0.004348
# (120.0, 150.0]      0.330435
# (150.0, 180.0]      0.247826
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.041304
# (-150.0, -120.0]    0.219565
# (60.0, 90.0]        0.121739
# (120.0, 150.0]      0.330435
# (150.0, 180.0]      0.247826
# Name: angle, dtype: float64
# fov_6_spor_pick_6_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.005146
# (-150.0, -120.0]    0.077187
# (-120.0, -90.0]     0.180103
# (-90.0, -60.0]      0.233276
# (-60.0, -30.0]      0.469983
# (-30.0, 0.0]        0.000000
# (0.0, 30.0]         0.000000
# (30.0, 60.0]        0.005146
# (60.0, 90.0]        0.015437
# (90.0, 120.0]       0.000000
# (120.0, 150.0]      0.003431
# (150.0, 180.0]      0.010292
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-150.0, -120.0]    0.077187
# (-120.0, -90.0]     0.180103
# (-90.0, -60.0]      0.233276
# (-60.0, -30.0]      0.469983
# Name: angle, dtype: float64
# fov_6_spor_pick_7_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.030474
# (-150.0, -120.0]    0.000000
# (-120.0, -90.0]     0.335214
# (-90.0, -60.0]      0.073363
# (-60.0, -30.0]      0.557562
# (-30.0, 0.0]        0.000000
# (0.0, 30.0]         0.002257
# (30.0, 60.0]        0.001129
# (60.0, 90.0]        0.000000
# (90.0, 120.0]       0.000000
# (120.0, 150.0]      0.000000
# (150.0, 180.0]      0.000000
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.030474
# (-120.0, -90.0]     0.335214
# (-90.0, -60.0]      0.073363
# (-60.0, -30.0]      0.557562
# Name: angle, dtype: float64
# fov_6_spor_pick_8_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.003484
# (-150.0, -120.0]    0.000000
# (-120.0, -90.0]     0.000000
# (-90.0, -60.0]      0.000000
# (-60.0, -30.0]      0.000000
# (-30.0, 0.0]        0.038328
# (0.0, 30.0]         0.247387
# (30.0, 60.0]        0.094077
# (60.0, 90.0]        0.006969
# (90.0, 120.0]       0.000000
# (120.0, 150.0]      0.108014
# (150.0, 180.0]      0.501742
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-30.0, 0.0]      0.038328
# (0.0, 30.0]       0.247387
# (30.0, 60.0]      0.094077
# (120.0, 150.0]    0.108014
# (150.0, 180.0]    0.501742
# Name: angle, dtype: float64
# fov_6_spor_pick_9_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.495238
# (-150.0, -120.0]    0.000000
# (-120.0, -90.0]     0.003175
# (-90.0, -60.0]      0.000000
# (-60.0, -30.0]      0.000000
# (-30.0, 0.0]        0.000000
# (0.0, 30.0]         0.453968
# (30.0, 60.0]        0.000000
# (60.0, 90.0]        0.006349
# (90.0, 120.0]       0.025397
# (120.0, 150.0]      0.003175
# (150.0, 180.0]      0.012698
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.495238
# (0.0, 30.0]         0.453968
# (90.0, 120.0]       0.025397
# Name: angle, dtype: float64
# fov_6_spor_pick_10_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.263027
# (-150.0, -120.0]    0.029777
# (-120.0, -90.0]     0.000000
# (-90.0, -60.0]      0.024814
# (-60.0, -30.0]      0.245658
# (-30.0, 0.0]        0.047146
# (0.0, 30.0]         0.000000
# (30.0, 60.0]        0.012407
# (60.0, 90.0]        0.079404
# (90.0, 120.0]       0.119107
# (120.0, 150.0]      0.091811
# (150.0, 180.0]      0.086849
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.263027
# (-150.0, -120.0]    0.029777
# (-90.0, -60.0]      0.024814
# (-60.0, -30.0]      0.245658
# (-30.0, 0.0]        0.047146
# (60.0, 90.0]        0.079404
# (90.0, 120.0]       0.119107
# (120.0, 150.0]      0.091811
# (150.0, 180.0]      0.086849
# Name: angle, dtype: float64
# fov_6_spor_pick_11_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.214979
# (-150.0, -120.0]    0.005548
# (-120.0, -90.0]     0.030513
# (-90.0, -60.0]      0.067961
# (-60.0, -30.0]      0.092926
# (-30.0, 0.0]        0.047157
# (0.0, 30.0]         0.034674
# (30.0, 60.0]        0.126214
# (60.0, 90.0]        0.002774
# (90.0, 120.0]       0.015257
# (120.0, 150.0]      0.092926
# (150.0, 180.0]      0.269071
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.214979
# (-120.0, -90.0]     0.030513
# (-90.0, -60.0]      0.067961
# (-60.0, -30.0]      0.092926
# (-30.0, 0.0]        0.047157
# (0.0, 30.0]         0.034674
# (30.0, 60.0]        0.126214
# (120.0, 150.0]      0.092926
# (150.0, 180.0]      0.269071
# Name: angle, dtype: float64
# fov_6_spor_pick_12_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.120980
# (-150.0, -120.0]    0.136294
# (-120.0, -90.0]     0.009188
# (-90.0, -60.0]      0.055130
# (-60.0, -30.0]      0.114855
# (-30.0, 0.0]        0.156202
# (0.0, 30.0]         0.137825
# (30.0, 60.0]        0.067381
# (60.0, 90.0]        0.107198
# (90.0, 120.0]       0.093415
# (120.0, 150.0]      0.000000
# (150.0, 180.0]      0.001531
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.120980
# (-150.0, -120.0]    0.136294
# (-90.0, -60.0]      0.055130
# (-60.0, -30.0]      0.114855
# (-30.0, 0.0]        0.156202
# (0.0, 30.0]         0.137825
# (30.0, 60.0]        0.067381
# (60.0, 90.0]        0.107198
# (90.0, 120.0]       0.093415
# Name: angle, dtype: float64
# fov_6_spor_pick_13_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.067708
# (-150.0, -120.0]    0.282986
# (-120.0, -90.0]     0.013889
# (-90.0, -60.0]      0.003472
# (-60.0, -30.0]      0.168403
# (-30.0, 0.0]        0.022569
# (0.0, 30.0]         0.088542
# (30.0, 60.0]        0.019097
# (60.0, 90.0]        0.055556
# (90.0, 120.0]       0.019097
# (120.0, 150.0]      0.234375
# (150.0, 180.0]      0.024306
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.067708
# (-150.0, -120.0]    0.282986
# (-60.0, -30.0]      0.168403
# (-30.0, 0.0]        0.022569
# (0.0, 30.0]         0.088542
# (60.0, 90.0]        0.055556
# (120.0, 150.0]      0.234375
# (150.0, 180.0]      0.024306
# Name: angle, dtype: float64
# fov_6_spor_pick_14_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.033445
# (-150.0, -120.0]    0.030100
# (-120.0, -90.0]     0.088629
# (-90.0, -60.0]      0.046823
# (-60.0, -30.0]      0.162207
# (-30.0, 0.0]        0.133779
# (0.0, 30.0]         0.198997
# (30.0, 60.0]        0.081940
# (60.0, 90.0]        0.020067
# (90.0, 120.0]       0.170569
# (120.0, 150.0]      0.025084
# (150.0, 180.0]      0.008361
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.033445
# (-150.0, -120.0]    0.030100
# (-120.0, -90.0]     0.088629
# (-90.0, -60.0]      0.046823
# (-60.0, -30.0]      0.162207
# (-30.0, 0.0]        0.133779
# (0.0, 30.0]         0.198997
# (30.0, 60.0]        0.081940
# (90.0, 120.0]       0.170569
# (120.0, 150.0]      0.025084
# Name: angle, dtype: float64
# fov_6_spor_pick_15_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.311787
# (-150.0, -120.0]    0.003802
# (-120.0, -90.0]     0.003802
# (-90.0, -60.0]      0.558935
# (-60.0, -30.0]      0.011407
# (-30.0, 0.0]        0.000000
# (0.0, 30.0]         0.000000
# (30.0, 60.0]        0.079848
# (60.0, 90.0]        0.003802
# (90.0, 120.0]       0.019011
# (120.0, 150.0]      0.007605
# (150.0, 180.0]      0.000000
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.311787
# (-90.0, -60.0]      0.558935
# (30.0, 60.0]        0.079848
# Name: angle, dtype: float64
# fov_6_spor_pick_16_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.006881
# (-150.0, -120.0]    0.261468
# (-120.0, -90.0]     0.048165
# (-90.0, -60.0]      0.025229
# (-60.0, -30.0]      0.116972
# (-30.0, 0.0]        0.073394
# (0.0, 30.0]         0.004587
# (30.0, 60.0]        0.004587
# (60.0, 90.0]        0.126147
# (90.0, 120.0]       0.112385
# (120.0, 150.0]      0.000000
# (150.0, 180.0]      0.220183
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-150.0, -120.0]    0.261468
# (-120.0, -90.0]     0.048165
# (-90.0, -60.0]      0.025229
# (-60.0, -30.0]      0.116972
# (-30.0, 0.0]        0.073394
# (60.0, 90.0]        0.126147
# (90.0, 120.0]       0.112385
# (150.0, 180.0]      0.220183
# Name: angle, dtype: float64
# fov_6_spor_pick_17_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.001961
# (-150.0, -120.0]    0.094118
# (-120.0, -90.0]     0.039216
# (-90.0, -60.0]      0.103922
# (-60.0, -30.0]      0.078431
# (-30.0, 0.0]        0.337255
# (0.0, 30.0]         0.000000
# (30.0, 60.0]        0.000000
# (60.0, 90.0]        0.005882
# (90.0, 120.0]       0.115686
# (120.0, 150.0]      0.037255
# (150.0, 180.0]      0.186275
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-150.0, -120.0]    0.094118
# (-120.0, -90.0]     0.039216
# (-90.0, -60.0]      0.103922
# (-60.0, -30.0]      0.078431
# (-30.0, 0.0]        0.337255
# (90.0, 120.0]       0.115686
# (120.0, 150.0]      0.037255
# (150.0, 180.0]      0.186275
# Name: angle, dtype: float64
# fov_6_spor_pick_18_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.115970
# (-150.0, -120.0]    0.169202
# (-120.0, -90.0]     0.007605
# (-90.0, -60.0]      0.000000
# (-60.0, -30.0]      0.184411
# (-30.0, 0.0]        0.106464
# (0.0, 30.0]         0.001901
# (30.0, 60.0]        0.015209
# (60.0, 90.0]        0.001901
# (90.0, 120.0]       0.091255
# (120.0, 150.0]      0.100760
# (150.0, 180.0]      0.205323
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.115970
# (-150.0, -120.0]    0.169202
# (-60.0, -30.0]      0.184411
# (-30.0, 0.0]        0.106464
# (90.0, 120.0]       0.091255
# (120.0, 150.0]      0.100760
# (150.0, 180.0]      0.205323
# Name: angle, dtype: float64
# fov_6_spor_pick_19_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.117330
# (-150.0, -120.0]    0.091496
# (-120.0, -90.0]     0.177610
# (-90.0, -60.0]      0.051668
# (-60.0, -30.0]      0.068891
# (-30.0, 0.0]        0.010764
# (0.0, 30.0]         0.059203
# (30.0, 60.0]        0.078579
# (60.0, 90.0]        0.036598
# (90.0, 120.0]       0.026911
# (120.0, 150.0]      0.222820
# (150.0, 180.0]      0.058127
# Name: angle, dtype: float64
# ...
# (-90.0, -60.0]      0.009091
# (-60.0, -30.0]      0.063636
# (-30.0, 0.0]        0.084091
# (0.0, 30.0]         0.031818
# (30.0, 60.0]        0.102273
# (60.0, 90.0]        0.154545
# (90.0, 120.0]       0.093182
# (120.0, 150.0]      0.147727
# (150.0, 180.0]      0.118182
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.138636
# (-120.0, -90.0]     0.054545
# (-60.0, -30.0]      0.063636
# (-30.0, 0.0]        0.084091
# (0.0, 30.0]         0.031818
# (30.0, 60.0]        0.102273
# (60.0, 90.0]        0.154545
# (90.0, 120.0]       0.093182
# (120.0, 150.0]      0.147727
# (150.0, 180.0]      0.118182
# Name: angle, dtype: float64
# fov_8_spor_pick_12_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.000000
# (-150.0, -120.0]    0.002778
# (-120.0, -90.0]     0.036111
# (-90.0, -60.0]      0.000000
# (-60.0, -30.0]      0.002778
# (-30.0, 0.0]        0.008333
# (0.0, 30.0]         0.152778
# (30.0, 60.0]        0.291667
# (60.0, 90.0]        0.394444
# (90.0, 120.0]       0.013889
# (120.0, 150.0]      0.097222
# (150.0, 180.0]      0.000000
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-120.0, -90.0]    0.036111
# (0.0, 30.0]        0.152778
# (30.0, 60.0]       0.291667
# (60.0, 90.0]       0.394444
# (120.0, 150.0]     0.097222
# Name: angle, dtype: float64
# fov_8_spor_pick_13_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.132
# (-150.0, -120.0]    0.072
# (-120.0, -90.0]     0.018
# (-90.0, -60.0]      0.034
# (-60.0, -30.0]      0.184
# (-30.0, 0.0]        0.004
# (0.0, 30.0]         0.004
# (30.0, 60.0]        0.092
# (60.0, 90.0]        0.068
# (90.0, 120.0]       0.068
# (120.0, 150.0]      0.140
# (150.0, 180.0]      0.184
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.132
# (-150.0, -120.0]    0.072
# (-90.0, -60.0]      0.034
# (-60.0, -30.0]      0.184
# (30.0, 60.0]        0.092
# (60.0, 90.0]        0.068
# (90.0, 120.0]       0.068
# (120.0, 150.0]      0.140
# (150.0, 180.0]      0.184
# Name: angle, dtype: float64
# fov_10_veg_pick_0_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.026076
# (-150.0, -120.0]    0.001304
# (-120.0, -90.0]     0.007823
# (-90.0, -60.0]      0.119948
# (-60.0, -30.0]      0.000000
# (-30.0, 0.0]        0.074316
# (0.0, 30.0]         0.108214
# (30.0, 60.0]        0.102999
# (60.0, 90.0]        0.146023
# (90.0, 120.0]       0.071708
# (120.0, 150.0]      0.183833
# (150.0, 180.0]      0.157757
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.026076
# (-90.0, -60.0]      0.119948
# (-30.0, 0.0]        0.074316
# (0.0, 30.0]         0.108214
# (30.0, 60.0]        0.102999
# (60.0, 90.0]        0.146023
# (90.0, 120.0]       0.071708
# (120.0, 150.0]      0.183833
# (150.0, 180.0]      0.157757
# Name: angle, dtype: float64
# fov_10_veg_pick_1_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.065054
# (-150.0, -120.0]    0.061718
# (-120.0, -90.0]     0.033361
# (-90.0, -60.0]      0.073394
# (-60.0, -30.0]      0.087573
# (-30.0, 0.0]        0.020851
# (0.0, 30.0]         0.097581
# (30.0, 60.0]        0.109258
# (60.0, 90.0]        0.038365
# (90.0, 120.0]       0.198499
# (120.0, 150.0]      0.163470
# (150.0, 180.0]      0.050876
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.065054
# (-150.0, -120.0]    0.061718
# (-120.0, -90.0]     0.033361
# (-90.0, -60.0]      0.073394
# (-60.0, -30.0]      0.087573
# (-30.0, 0.0]        0.020851
# (0.0, 30.0]         0.097581
# (30.0, 60.0]        0.109258
# (60.0, 90.0]        0.038365
# (90.0, 120.0]       0.198499
# (120.0, 150.0]      0.163470
# (150.0, 180.0]      0.050876
# Name: angle, dtype: float64
# fov_9_veg_pick_0_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.033415
# (-150.0, -120.0]    0.158109
# (-120.0, -90.0]     0.109209
# (-90.0, -60.0]      0.070090
# (-60.0, -30.0]      0.370823
# (-30.0, 0.0]        0.090465
# (0.0, 30.0]         0.061940
# (30.0, 60.0]        0.048085
# (60.0, 90.0]        0.025265
# (90.0, 120.0]       0.011410
# (120.0, 150.0]      0.010595
# (150.0, 180.0]      0.010595
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.033415
# (-150.0, -120.0]    0.158109
# (-120.0, -90.0]     0.109209
# (-90.0, -60.0]      0.070090
# (-60.0, -30.0]      0.370823
# (-30.0, 0.0]        0.090465
# (0.0, 30.0]         0.061940
# (30.0, 60.0]        0.048085
# (60.0, 90.0]        0.025265
# Name: angle, dtype: float64
# fov_9_veg_pick_1_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.164257
# (-150.0, -120.0]    0.042972
# (-120.0, -90.0]     0.037349
# (-90.0, -60.0]      0.038153
# (-60.0, -30.0]      0.064659
# (-30.0, 0.0]        0.028916
# (0.0, 30.0]         0.124498
# (30.0, 60.0]        0.071084
# (60.0, 90.0]        0.177510
# (90.0, 120.0]       0.224900
# (120.0, 150.0]      0.014056
# (150.0, 180.0]      0.011647
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.164257
# (-150.0, -120.0]    0.042972
# (-120.0, -90.0]     0.037349
# (-90.0, -60.0]      0.038153
# (-60.0, -30.0]      0.064659
# (-30.0, 0.0]        0.028916
# (0.0, 30.0]         0.124498
# (30.0, 60.0]        0.071084
# (60.0, 90.0]        0.177510
# (90.0, 120.0]       0.224900
# Name: angle, dtype: float64
# fov_9_veg_pick_2_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.076176
# (-150.0, -120.0]    0.087835
# (-120.0, -90.0]     0.042752
# (-90.0, -60.0]      0.058298
# (-60.0, -30.0]      0.115041
# (-30.0, 0.0]        0.164788
# (0.0, 30.0]         0.183055
# (30.0, 60.0]        0.057909
# (60.0, 90.0]        0.052468
# (90.0, 120.0]       0.052079
# (120.0, 150.0]      0.075787
# (150.0, 180.0]      0.033813
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.076176
# (-150.0, -120.0]    0.087835
# (-120.0, -90.0]     0.042752
# (-90.0, -60.0]      0.058298
# (-60.0, -30.0]      0.115041
# (-30.0, 0.0]        0.164788
# (0.0, 30.0]         0.183055
# (30.0, 60.0]        0.057909
# (60.0, 90.0]        0.052468
# (90.0, 120.0]       0.052079
# (120.0, 150.0]      0.075787
# (150.0, 180.0]      0.033813
# Name: angle, dtype: float64
# fov_12_spor_pick_0_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.206144
# (-150.0, -120.0]    0.059822
# (-120.0, -90.0]     0.067098
# (-90.0, -60.0]      0.094584
# (-60.0, -30.0]      0.129345
# (-30.0, 0.0]        0.061439
# (0.0, 30.0]         0.035570
# (30.0, 60.0]        0.066289
# (60.0, 90.0]        0.077607
# (90.0, 120.0]       0.100243
# (120.0, 150.0]      0.024252
# (150.0, 180.0]      0.077607
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.206144
# (-150.0, -120.0]    0.059822
# (-120.0, -90.0]     0.067098
# (-90.0, -60.0]      0.094584
# (-60.0, -30.0]      0.129345
# (-30.0, 0.0]        0.061439
# (0.0, 30.0]         0.035570
# (30.0, 60.0]        0.066289
# (60.0, 90.0]        0.077607
# (90.0, 120.0]       0.100243
# (120.0, 150.0]      0.024252
# (150.0, 180.0]      0.077607
# Name: angle, dtype: float64
# fov_12_spor_pick_1_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.244554
# (-150.0, -120.0]    0.101980
# (-120.0, -90.0]     0.005941
# (-90.0, -60.0]      0.000000
# (-60.0, -30.0]      0.000000
# (-30.0, 0.0]        0.001980
# (0.0, 30.0]         0.002970
# (30.0, 60.0]        0.211881
# (60.0, 90.0]        0.021782
# (90.0, 120.0]       0.167327
# (120.0, 150.0]      0.181188
# (150.0, 180.0]      0.060396
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.244554
# (-150.0, -120.0]    0.101980
# (30.0, 60.0]        0.211881
# (60.0, 90.0]        0.021782
# (90.0, 120.0]       0.167327
# (120.0, 150.0]      0.181188
# (150.0, 180.0]      0.060396
# Name: angle, dtype: float64
# fov_12_spor_pick_2_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.079190
# (-150.0, -120.0]    0.011050
# (-120.0, -90.0]     0.294659
# (-90.0, -60.0]      0.410681
# (-60.0, -30.0]      0.001842
# (-30.0, 0.0]        0.000000
# (0.0, 30.0]         0.000000
# (30.0, 60.0]        0.003683
# (60.0, 90.0]        0.047882
# (90.0, 120.0]       0.029466
# (120.0, 150.0]      0.103131
# (150.0, 180.0]      0.018416
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.079190
# (-120.0, -90.0]     0.294659
# (-90.0, -60.0]      0.410681
# (60.0, 90.0]        0.047882
# (90.0, 120.0]       0.029466
# (120.0, 150.0]      0.103131
# Name: angle, dtype: float64
# fov_12_spor_pick_3_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.000000
# (-150.0, -120.0]    0.027165
# (-120.0, -90.0]     0.069610
# (-90.0, -60.0]      0.426146
# (-60.0, -30.0]      0.028862
# (-30.0, 0.0]        0.118846
# (0.0, 30.0]         0.161290
# (30.0, 60.0]        0.050934
# (60.0, 90.0]        0.110357
# (90.0, 120.0]       0.006791
# (120.0, 150.0]      0.000000
# (150.0, 180.0]      0.000000
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-150.0, -120.0]    0.027165
# (-120.0, -90.0]     0.069610
# (-90.0, -60.0]      0.426146
# (-60.0, -30.0]      0.028862
# (-30.0, 0.0]        0.118846
# (0.0, 30.0]         0.161290
# (30.0, 60.0]        0.050934
# (60.0, 90.0]        0.110357
# Name: angle, dtype: float64
# fov_12_spor_pick_4_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.055256
# (-150.0, -120.0]    0.040431
# (-120.0, -90.0]     0.209569
# (-90.0, -60.0]      0.047170
# (-60.0, -30.0]      0.083558
# (-30.0, 0.0]        0.105795
# (0.0, 30.0]         0.043127
# (30.0, 60.0]        0.139488
# (60.0, 90.0]        0.094340
# (90.0, 120.0]       0.137466
# (120.0, 150.0]      0.021563
# (150.0, 180.0]      0.022237
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.055256
# (-150.0, -120.0]    0.040431
# (-120.0, -90.0]     0.209569
# (-90.0, -60.0]      0.047170
# (-60.0, -30.0]      0.083558
# (-30.0, 0.0]        0.105795
# (0.0, 30.0]         0.043127
# (30.0, 60.0]        0.139488
# (60.0, 90.0]        0.094340
# (90.0, 120.0]       0.137466
# (120.0, 150.0]      0.021563
# (150.0, 180.0]      0.022237
# Name: angle, dtype: float64
# fov_12_spor_pick_5_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.018411
# (-150.0, -120.0]    0.009690
# (-120.0, -90.0]     0.003876
# (-90.0, -60.0]      0.004845
# (-60.0, -30.0]      0.001938
# (-30.0, 0.0]        0.013566
# (0.0, 30.0]         0.199612
# (30.0, 60.0]        0.101744
# (60.0, 90.0]        0.072674
# (90.0, 120.0]       0.215116
# (120.0, 150.0]      0.260659
# (150.0, 180.0]      0.097868
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (0.0, 30.0]       0.199612
# (30.0, 60.0]      0.101744
# (60.0, 90.0]      0.072674
# (90.0, 120.0]     0.215116
# (120.0, 150.0]    0.260659
# (150.0, 180.0]    0.097868
# Name: angle, dtype: float64
# fov_12_spor_pick_6_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.472050
# (-150.0, -120.0]    0.001553
# (-120.0, -90.0]     0.004658
# (-90.0, -60.0]      0.000000
# (-60.0, -30.0]      0.000000
# (-30.0, 0.0]        0.000000
# (0.0, 30.0]         0.000000
# (30.0, 60.0]        0.000000
# (60.0, 90.0]        0.000000
# (90.0, 120.0]       0.000000
# (120.0, 150.0]      0.003106
# (150.0, 180.0]      0.518634
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.472050
# (150.0, 180.0]      0.518634
# Name: angle, dtype: float64
# fov_12_spor_pick_7_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.219153
# (-150.0, -120.0]    0.013812
# (-120.0, -90.0]     0.052486
# (-90.0, -60.0]      0.142726
# (-60.0, -30.0]      0.150092
# (-30.0, 0.0]        0.254144
# (0.0, 30.0]         0.011050
# (30.0, 60.0]        0.035912
# (60.0, 90.0]        0.003683
# (90.0, 120.0]       0.001842
# (120.0, 150.0]      0.023941
# (150.0, 180.0]      0.091160
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.219153
# (-120.0, -90.0]     0.052486
# (-90.0, -60.0]      0.142726
# (-60.0, -30.0]      0.150092
# (-30.0, 0.0]        0.254144
# (30.0, 60.0]        0.035912
# (120.0, 150.0]      0.023941
# (150.0, 180.0]      0.091160
# Name: angle, dtype: float64
# fov_12_spor_pick_8_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.144035
# (-150.0, -120.0]    0.344145
# (-120.0, -90.0]     0.089610
# (-90.0, -60.0]      0.080264
# (-60.0, -30.0]      0.072567
# (-30.0, 0.0]        0.095657
# (0.0, 30.0]         0.053876
# (30.0, 60.0]        0.012644
# (60.0, 90.0]        0.004398
# (90.0, 120.0]       0.015393
# (120.0, 150.0]      0.034085
# (150.0, 180.0]      0.053326
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.144035
# (-150.0, -120.0]    0.344145
# (-120.0, -90.0]     0.089610
# (-90.0, -60.0]      0.080264
# (-60.0, -30.0]      0.072567
# (-30.0, 0.0]        0.095657
# (0.0, 30.0]         0.053876
# (120.0, 150.0]      0.034085
# (150.0, 180.0]      0.053326
# Name: angle, dtype: float64
# fov_12_spor_pick_9_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.210843
# (-150.0, -120.0]    0.212048
# (-120.0, -90.0]     0.268675
# (-90.0, -60.0]      0.103614
# (-60.0, -30.0]      0.053012
# (-30.0, 0.0]        0.001205
# (0.0, 30.0]         0.000000
# (30.0, 60.0]        0.004819
# (60.0, 90.0]        0.080723
# (90.0, 120.0]       0.013253
# (120.0, 150.0]      0.021687
# (150.0, 180.0]      0.030120
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.210843
# (-150.0, -120.0]    0.212048
# (-120.0, -90.0]     0.268675
# (-90.0, -60.0]      0.103614
# (-60.0, -30.0]      0.053012
# (60.0, 90.0]        0.080723
# (120.0, 150.0]      0.021687
# (150.0, 180.0]      0.030120
# Name: angle, dtype: float64
# fov_12_spor_pick_10_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.011295
# (-150.0, -120.0]    0.078313
# (-120.0, -90.0]     0.277108
# (-90.0, -60.0]      0.530120
# (-60.0, -30.0]      0.047440
# (-30.0, 0.0]        0.038404
# (0.0, 30.0]         0.009036
# (30.0, 60.0]        0.000000
# (60.0, 90.0]        0.000000
# (90.0, 120.0]       0.000000
# (120.0, 150.0]      0.000000
# (150.0, 180.0]      0.008283
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-150.0, -120.0]    0.078313
# (-120.0, -90.0]     0.277108
# (-90.0, -60.0]      0.530120
# (-60.0, -30.0]      0.047440
# (-30.0, 0.0]        0.038404
# Name: angle, dtype: float64
# fov_12_spor_pick_11_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.040913
# (-150.0, -120.0]    0.020932
# (-120.0, -90.0]     0.058991
# (-90.0, -60.0]      0.086584
# (-60.0, -30.0]      0.030447
# (-30.0, 0.0]        0.141770
# (0.0, 30.0]         0.031399
# (30.0, 60.0]        0.246432
# (60.0, 90.0]        0.158896
# (90.0, 120.0]       0.022835
# (120.0, 150.0]      0.008563
# (150.0, 180.0]      0.152236
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.040913
# (-150.0, -120.0]    0.020932
# (-120.0, -90.0]     0.058991
# (-90.0, -60.0]      0.086584
# (-60.0, -30.0]      0.030447
# (-30.0, 0.0]        0.141770
# (0.0, 30.0]         0.031399
# (30.0, 60.0]        0.246432
# (60.0, 90.0]        0.158896
# (90.0, 120.0]       0.022835
# (150.0, 180.0]      0.152236
# Name: angle, dtype: float64
# fov_12_spor_pick_12_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.233687
# (-150.0, -120.0]    0.106222
# (-120.0, -90.0]     0.115326
# (-90.0, -60.0]      0.188164
# (-60.0, -30.0]      0.168437
# (-30.0, 0.0]        0.028832
# (0.0, 30.0]         0.012140
# (30.0, 60.0]        0.000000
# (60.0, 90.0]        0.036419
# (90.0, 120.0]       0.012140
# (120.0, 150.0]      0.024279
# (150.0, 180.0]      0.074355
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.233687
# (-150.0, -120.0]    0.106222
# (-120.0, -90.0]     0.115326
# (-90.0, -60.0]      0.188164
# (-60.0, -30.0]      0.168437
# (-30.0, 0.0]        0.028832
# (60.0, 90.0]        0.036419
# (120.0, 150.0]      0.024279
# (150.0, 180.0]      0.074355
# Name: angle, dtype: float64
# fov_12_spor_pick_13_ring_0_rot_yz_update.hdf5
# angle
# (-180.0, -150.0]    0.082225
# (-150.0, -120.0]    0.085852
# (-120.0, -90.0]     0.309553
# (-90.0, -60.0]      0.211608
# (-60.0, -30.0]      0.189843
# (-30.0, 0.0]        0.002418
# (0.0, 30.0]         0.033857
# (30.0, 60.0]        0.001209
# (60.0, 90.0]        0.070133
# (90.0, 120.0]       0.012092
# (120.0, 150.0]      0.001209
# (150.0, 180.0]      0.000000
# Name: angle, dtype: float64
# perc_locs_per_segments_filled angle
# (-180.0, -150.0]    0.082225
# (-150.0, -120.0]    0.085852
# (-120.0, -90.0]     0.309553
# (-90.0, -60.0]      0.211608
# (-60.0, -30.0]      0.189843
# (0.0, 30.0]         0.033857
# (60.0, 90.0]        0.070133
# Name: angle, dtype: float64
